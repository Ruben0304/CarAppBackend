# %%
from pymongo import MongoClient

# Conectarse a la base de datos
client = MongoClient("mongodb+srv://ruben:zixelowe1@personal.yycznyk.mongodb.net/")  # 

# Seleccionar una base de datos
db = client["Prueba_de_mongo"]

# Seleccionar una colección (equivalente a una tabla en bases de datos SQL)
animales = db["Animales"]

# %%
result = animales.find()

print("Lista de animales\n")
for i in result:
    print(f"Nombre: {i.get('name', 'N/A')}")
    print(f"Especie: {i.get('species', 'N/A')}")
    print(f"Cruces: {i.get('crosses','N/A')}")
    print(f"Edad: {i.get('age', 'N/A')}")
    print(f"Tipo: {i.get('type','N/A')}")
    print()
# Out:
# Lista de animales
#
# Nombre: Norberto
# Especie: dragon
# Cruces: N/A
# Edad: 1
# Tipo: N/A
#
# Nombre: Picket
# Especie: Bowtruckle
# Cruces: N/A
# Edad: 3
# Tipo: N/A
#
# Nombre: Voltur
# Especie: dragon
# Cruces: N/A
# Edad: 4
# Tipo: Ucranian Ironbelly
#
# Nombre: Teddy
# Especie: Niffler
# Cruces: N/A
# Edad: 5
# Tipo: N/A
#
# Nombre: Puas
# Especie: Nundu
# Cruces: 5
# Edad: 10
# Tipo: N/A
#
# Nombre: Broddy
# Especie: Wyvern
# Cruces: N/A
# Edad: 3
# Tipo: N/A

# %%
# INSERCIONES 
animales.insert_many([
    {"name":"Puas",
     "species": "Nundu",
     "age": 10,
     "crosses": 5
     },
    {"name":"Broddy",
     "species": "Wyvern",
     "age": 3
     }
])
# Out:
# InsertManyResult([ObjectId('670adcce3914c5087e239c7b'), ObjectId('670adcce3914c5087e239c7c')], acknowledged=True)

# %%
#ACTUALIZACIONES

# %%
#ELIMINACIONES
